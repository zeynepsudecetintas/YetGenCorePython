# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
def final_velocity(initial_velocity, acceleration, time):
    final_velocity = initial_velocity + acceleration * time
    return final_velocity

vi = float(input("İlk hızı girin (m/s): "))
a = float(input("İvmeyi girin (m/s^2): "))
t = float(input("Zamanı girin (s): "))

vf = final_velocity(vi, a, t)

print(f"Son hız: {vf} m/s")
# Out:
# Son hız: 65.0 m/s

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mukemmelSayi(number):
    bolenToplam = sum(i for i in range(1, number) if number % i == 0)

    return bolenToplam == number

for num in range(1, 1001):
    if mukemmelSayi(num):
        print(num)
# Out:
# 6
# 28
# 496

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisagorUcgeni(limit):
    for a in range(1, limit + 1):
        for b in range(a, limit + 1):
            c = (a**2 + b**2)**0.5
            if c.is_integer() and c <= limit:
                print(f"({a}, {b}, {int(c)})")

pisagorUcgeni(100)
# Out:
# (3, 4, 5)
# (5, 12, 13)
# (6, 8, 10)
# (7, 24, 25)
# (8, 15, 17)
# (9, 12, 15)
# (9, 40, 41)
# (10, 24, 26)
# (11, 60, 61)
# (12, 16, 20)
# (12, 35, 37)
# (13, 84, 85)
# (14, 48, 50)
# (15, 20, 25)
# (15, 36, 39)
# (16, 30, 34)
# (16, 63, 65)
# (18, 24, 30)
# (18, 80, 82)
# (20, 21, 29)
# (20, 48, 52)
# (21, 28, 35)
# (21, 72, 75)
# (24, 32, 40)
# (24, 45, 51)
# (24, 70, 74)
# (25, 60, 65)
# (27, 36, 45)
# (28, 45, 53)
# (28, 96, 100)
# (30, 40, 50)
# (30, 72, 78)
# (32, 60, 68)
# (33, 44, 55)
# (33, 56, 65)
# (35, 84, 91)
# (36, 48, 60)
# (36, 77, 85)
# (39, 52, 65)
# (39, 80, 89)
# (40, 42, 58)
# (40, 75, 85)
# (42, 56, 70)
# (45, 60, 75)
# (48, 55, 73)
# (48, 64, 80)
# (51, 68, 85)
# (54, 72, 90)
# (57, 76, 95)
# (60, 63, 87)
# (60, 80, 100)
# (65, 72, 97)

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math

def kutuSayisi(height, width, kutuBasiKaplama):
    area = height * width
    cans_needed = math.ceil(area / kutuBasiKaplama)
    return cans_needed

height = float(input("Duvar yüksekliğini girin (metre): "))
width = float(input("Duvar genişliğini girin (metre): "))
kutuBasiKaplama = 5  # Bir kutu boyanın kapladığı alan (metrekare)

cans = kutuSayisi(height, width, kutuBasiKaplama)

print(f"Gerekli boya kutusu sayısı: {cans}")
# Out:
# Gerekli boya kutusu sayısı: 3

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
def unluUnsuzSay(word):
    vowels = "aeıioöuüAEIİOÖUÜ"
    vowel_count = 0
    consonant_count = 0

    for char in word:
        if char.isalpha(): 
            if char in vowels:
                vowel_count += 1
            else:
                consonant_count += 1

    return vowel_count, consonant_count

word = input("Bir kelime giriniz: ")

vowels, consonants = unluUnsuzSay(word)

print(f"Kelimeniz: {word}")
print(f"Ünlü harf sayısı: {vowels}")
print(f"Ünsüz harf sayısı: {consonants}")
# Out:
# Kelimeniz: kaplumbağa
# Ünlü harf sayısı: 4
# Ünsüz harf sayısı: 6

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def CiftSayilar(numbers):
    for number in numbers:
        if number % 2 == 0:
            print(number)

numbers = input("Bir sayı listesi girin, girdiğiniz sayıları virgül ile ayırınız: ")

numbers_list = [int(num) for num in numbers.split(",")]

print(f"Listeniz: {numbers_list}")
print("Çift sayılar:")
CiftSayilar(numbers_list)
# Out:
# Listeniz: [5, 8, 9, 23, 10, 2902, 99, 55, 89, 1000]
# Çift sayılar:
# 8
# 10
# 2902
# 1000

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def ozyinelemeliFonksiyon(n):
    if n == 0:
        return 0
    else:
        return n + ozyinelemeliFonksiyon(n - 1)

result = ozyinelemeliFonksiyon(10)

print(f"0'dan 10'a kadar olan sayıların toplamı: {result}")
# Out:
# 0'dan 10'a kadar olan sayıların toplamı: 55
